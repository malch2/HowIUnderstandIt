# %% [markdown]
# https://docs.scipy.org/doc/scipy/reference/tutorial/fftpack.html

# %%
from scipy.fftpack import fft
import matplotlib.pyplot as plt
import numpy as np

# %%
N = 600 #number of sample points

# %%
dt = 1./800 #sample spacing

# %%
x = np.linspace(0, N*dt, N)
y = np.sin(50*2*np.pi*x) + np.sin(80*2*np.pi*x)

# %%
yf = fft(y)
xf = np.linspace(0, 1./(2*dt), N//2)

# %%
xf.shape, yf.shape
# Out:
# ((300,), (600,))

# %%
plt.plot(xf, 2./N * np.abs(yf[:N//2]))
plt.grid()
# plt.xlim([0, 100])
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# My code for DFT:

# %%
# %%time
Y = np.zeros_like(y)
for kk in range(N):
    Yk=0.0
    for ii in range(N):
        Yk += y[ii] * np.exp(-2j*np.pi*kk*ii/N)
        Yk_abs = np.abs(Yk)
    Y[kk] = Yk_abs
# Out:
# CPU times: user 2.85 s, sys: 15.9 ms, total: 2.87 s
# Wall time: 2.89 s

# %%
plt.plot(xf, 2./N * Y[:N//2], "r.-")
plt.bar(xf, 2./N * Y[:N//2])
plt.grid()
plt.show()

# %%
plt.plot(xf, 2./N * Y[:N//2], "r.-")
plt.bar(xf, 2./N * Y[:N//2])
plt.grid()
plt.xlim([0, 100])
plt.show()
